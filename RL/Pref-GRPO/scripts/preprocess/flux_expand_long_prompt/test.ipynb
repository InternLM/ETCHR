# %%
import json
with open("/mnt/shared-storage-user/mllm/xinglong/Pref-GRPO/data/expand_long_prompt_rl_embeddings/videos2caption.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# %%
data[5]
# Out:
# {'original_prompt': 'The Pyramid of Khufu in Egypt hangs in mid-air, and a huge shadow hangs over the modern city below.',
#  'generated_prompt': 'The massive Pyramid of Khufu hangs impossibly in the sky over a vast, modern metropolis. Its ancient, sandy-colored limestone blocks are rendered in hyper-realistic detail, showing cracks and erosion under a brilliant, sunlit sky. A gigantic, perfectly defined triangular shadow is cast down, blanketing a significant portion of the city below. This colossal shadow engulfs gleaming skyscrapers, intricate road networks, and residential areas in an unnatural darkness, creating a stark, high-contrast visual between the illuminated ancient structure and the shadowed contemporary world.',
# ...
